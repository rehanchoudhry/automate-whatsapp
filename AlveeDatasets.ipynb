# %%
import pandas as pd

# %%
# !git config - global user.name "rehanchoudhry"
# !git config - global user.email "rehanchoudhry@gmail.com"
# Out:
# git: 'config - global' is not a git command. See 'git --help'.
# git: 'config - global' is not a git command. See 'git --help'.

# %%
# !git clone https://rehanchoudhry:glpat-upn_aD2efRgK3ozmuFeQ@gitlab.com/rehanchoudhry/HelloWorld.git
# Out:
# Cloning into 'HelloWorld'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# %cd HelloWorld/
# !git status
# Out:
# /content/HelloWorld
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	HelloWorld/
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# Out:
# git: 'config - global' is not a git command. See 'git --help'.
# git: 'config - global' is not a git command. See 'git --help'.
# fatal: pathspec 'AlveeDatasets.ipynb' did not match any files
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@0a690708d1c7.(none)')
# error: src refspec master does not match any.
# error: failed to push some refs to 'https://rehanchoudhry:glpat-upn_aD2efRgK3ozmuFeQ@gitlab.com/rehanchoudhry/HelloWorld.git'

# %%
df = pd.read_csv('/content/drive/MyDrive/Alvee/ACSST5Y2019.S2701-Data.csv',skiprows=[1])

# %%
df.head()
# Out:
#            GEO_ID                  NAME  \
# 0       Geography  Geographic Area Name
# 1  8600000US30165           ZCTA5 30165
# 2  8600000US31905           ZCTA5 31905
# 3  8600000US35004           ZCTA5 35004
# 4  8600000US35005           ZCTA5 35005
#
#                                       S2701_C01_001E  \
# 0  Estimate!!Total!!Civilian noninstitutionalized...
# 1                                              41111
# 2                                               9023
# 3                                              12019
# 4                                               7332
#
#                                      S2701_C01_001EA  \
# 0  Annotation of Estimate!!Total!!Civilian nonins...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       S2701_C01_001M  \
# ...

# %%
df.columns
# Out:
# Index(['GEO_ID', 'NAME', 'S2701_C01_001E', 'S2701_C01_001EA', 'S2701_C01_001M',
#        'S2701_C01_001MA', 'S2701_C01_002E', 'S2701_C01_002EA',
#        'S2701_C01_002M', 'S2701_C01_002MA',
#        ...
#        'S2701_C05_059EA', 'S2701_C05_060E', 'S2701_C05_060M',
#        'S2701_C05_060MA', 'S2701_C05_060EA', 'S2701_C05_061E',
#        'S2701_C05_061M', 'S2701_C05_061MA', 'S2701_C05_061EA',
#        'Unnamed: 1222'],
#       dtype='object', length=1223)

# %%
df = df[['GEO_ID', 'NAME','S2701_C05_016E']]

# %%
df[df['S2701_C05_016E'].astype(float)>'65']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-a9fa1c13e630> in <module>
# ----> 1 df[df['S2701_C05_016E'].astype(float)>'65']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df.sort_values(by='S2701_C05_016E', ascending=False)
# Out:
#              GEO_ID         NAME S2701_C05_016E
# 440  8600000US36351  ZCTA5 36351            9.9
# 56   8600000US35096  ZCTA5 35096            9.9
# 331  8600000US36024  ZCTA5 36024            9.9
# 328  8600000US36017  ZCTA5 36017            9.8
# 387  8600000US36116  ZCTA5 36116            9.8
# ..              ...          ...            ...
# 209  8600000US35615  ZCTA5 35615              -
# 555  8600000US36616  ZCTA5 36616              -
# 384  8600000US36112  ZCTA5 36112              -
# 144  8600000US35457  ZCTA5 35457              -
# 477  8600000US36476  ZCTA5 36476              -
#
# [646 rows x 3 columns]

# %%
df[df['S2701_C05_016E'].str.contains('100')]
# Out:
#              GEO_ID         NAME S2701_C05_016E
# 7    8600000US35013  ZCTA5 35013          100.0
# 44   8600000US35074  ZCTA5 35074          100.0
# 405  8600000US36267  ZCTA5 36267          100.0

# %%
df.loc[df['GEO_ID'] == '8600000US30165']
# Out:
#            GEO_ID         NAME S2701_C05_016E
# 0  8600000US30165  ZCTA5 30165           14.2

# %%
# !pip install census
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install censusgeocode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 54 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
from censusgeocode import CensusGeocode

# %%
cg = CensusGeocode(benchmark="Public_AR_Current", vintage="Census2020_Current")
#again here we are hardcoding this year value, there are so many hardcoded values we need
#to keep track

# %%
 address = {}
 address['line']="1650 E 79th St"
 address['city'] = "Chicago"
 address['state'] = "IL"
 address['postalCode'] = "60649"
completeAdress =  f"{address['line']}, {address['city']}, {address['state']}, {address['postalCode']}"

# %%
print(completeAdress)
# Out:
# 1650 E 79th St, Chicago, IL, 60649

# %%
 response: dict = cg.onelineaddress(completeAdress)

# %%
print(response)
# Out:
# [{'tigerLine': {'side': 'L', 'tigerLineId': '111775219'}, 'geographies': {'2018 State Legislative Districts - Upper': [{'POP100': 247643, 'GEOID': '17003', 'CENTLAT': '+41.8078075', 'AREAWATER': 376437, 'STATE': '17', 'BASENAME': '3', 'OID': '212704492478322', 'LSADC': 'LU', 'SLDU': '003', 'FUNCSTAT': 'N', 'INTPTLAT': '+41.8041071', 'NAME': 'State Senate District 3', 'OBJECTID': 116, 'CENTLON': '-087.6370472', 'LSY': '2018', 'AREALAND': 44465316, 'INTPTLON': '-087.6385628', 'HU100': 137123, 'MTFCC': 'G5210', 'LDTYP': 'O'}], 'States': [{'STATENS': '01779784', 'POP100': 12812508, 'GEOID': '17', 'CENTLAT': '+40.1006037', 'AREAWATER': 6216539665, 'STATE': '17', 'BASENAME': 'Illinois', 'STUSAB': 'IL', 'OID': '27470100360203', 'LSADC': '00', 'FUNCSTAT': 'A', 'INTPTLAT': '+40.1028754', 'DIVISION': '3', 'NAME': 'Illinois', 'REGION': '2', 'OBJECTID': 25, 'CENTLON': '-089.1500819', 'AREALAND': 143778515726, 'INTPTLON': '-089.1526108', 'HU100': 5426429, 'MTFCC': 'G4000', 'UR': ''}], 'Combined S
# ...

# %%
print(response.get('zip'))
#print(response.get("tabllk2010"))
#print(response.get("geo_id"))
#print(response.get("zip"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-fcb05df3a52e> in <module>
# ----> 1 print(response.get('zip'))
#       2 #print(response.get("tabllk2010"))
#       3 #print(response.get("geo_id"))
#       4 #print(response.get("zip"))
#
# AttributeError: 'AddressResult' object has no attribute 'get'

# %%
df_cols = pd.read_csv('/content/drive/MyDrive/Alvee/ACSST5Y2019.S2701-Column-Metadata.csv')

# %%
df_cols.head()
# Out:
#        Column Name                                              Label
# 0           GEO_ID                                          Geography
# 1             NAME                               Geographic Area Name
# 2   S2701_C01_001E  Estimate!!Total!!Civilian noninstitutionalized...
# 3  S2701_C01_001EA  Annotation of Estimate!!Total!!Civilian nonins...
# 4   S2701_C01_001M  Margin of Error!!Total!!Civilian noninstitutio...

# %%
df_cols[df_cols["Label"].str.contains("Percent Uninsured") & df_cols["Label"].str.contains("RACE") ]
# Out:
#           Column Name                                              Label
# 1038   S2701_C05_016E  Estimate!!Percent Uninsured!!Civilian noninsti...
# 1039  S2701_C05_016EA  Annotation of Estimate!!Percent Uninsured!!Civ...
# 1040   S2701_C05_016M  Margin of Error!!Percent Uninsured!!Civilian n...
# 1041  S2701_C05_016MA  Annotation of Margin of Error!!Percent Uninsur...
# 1042   S2701_C05_017E  Estimate!!Percent Uninsured!!Civilian noninsti...
# 1043  S2701_C05_017EA  Annotation of Estimate!!Percent Uninsured!!Civ...
# 1044   S2701_C05_017M  Margin of Error!!Percent Uninsured!!Civilian n...
# 1045  S2701_C05_017MA  Annotation of Margin of Error!!Percent Uninsur...
# 1046   S2701_C05_018E  Estimate!!Percent Uninsured!!Civilian noninsti...
# 1047  S2701_C05_018EA  Annotation of Estimate!!Percent Uninsured!!Civ...
# 1048   S2701_C05_018M  Margin of Error!!Percent Uninsured!!Civilian n...
# 1049  S2701_C05_018MA  Annotation of Margin of Error!!Percent Uninsur...
# ...

# %%
#health insurance

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {"White":"S2701_C05_016E","Black_or_African_American":"S2701_C05_017E","American_Indian_or_Alaska_Native":"S2701_C05_018E","sian":"S2701_C05_019E","Native_Hawaiian_or_Other_Pacific_Islander":"S2701_C05_020E","Some_other_race":"S2701_C05_021E","Two_or_more_races":"S2701_C05_022E","Hispanic_or_Latino_origin_(of_any_race)":"S2701_C05_023E","White_alone,_not_Hispanic_or_Latino":"S2701_C05_024E"}

folderPath = "/content/drive/MyDrive/Alvee/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Health_Insurance_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#public transporation

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

#races = {"White":"S2701_C05_016E","Black_or_African_American":"S2701_C05_017E","American_Indian_or_Alaska_Native":"S2701_C05_018E","sian":"S2701_C05_019E","Native_Hawaiian_or_Other_Pacific_Islander":"S2701_C05_020E","Some_other_race":"S2701_C05_021E","Two_or_more_races":"S2701_C05_022E","Hispanic_or_Latino_origin_(of_any_race)":"S2701_C05_023E","White_alone,_not_Hispanic_or_Latino":"S2701_C05_024E"}
races = {"White":"S0802_C04_012E","Black_or_African_American":"S0802_C04_013E","American_Indian_or_Alaska_Native":"S0802_C04_014E","Asian":"S0802_C04_015E","Native_Hawaiian_or_Other_Pacific_Islander":"S0802_C04_016E","Some_other_race":"S0802_C04_017E","Two_or_more_races":"S0802_C04_018E","Hispanic_or_Latino_origin_(of_any_race)":"S0802_C04_019E","White_alone,_not_Hispanic_or_Latino":"S0802_C04_020E"}
folderPath = "/content/drive/MyDrive/Alvee/Public_Transportation/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Public_Transportation_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#english_proficiency_

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/english_proficiency/"


for st in states:
  #print(st)
  #print(states[st])
  
  #os.mkdir("temp")

  FIPSStateNumericCode = str(st).zfill(2)
  OfficialUSPSCode = str(states[st])
  path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME,S1601_C02_003E&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
  File = folderPath + "english_proficiency_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

  print(path)
  print(File)
  df = pd.read_json (path)
  df.to_csv (File, index = None)

# %%
#kitchen_facilities

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/kitchen_facilities/"


for st in states:
  #print(st)
  #print(states[st])
  
  #os.mkdir("temp")

  FIPSStateNumericCode = str(st).zfill(2)
  OfficialUSPSCode = str(states[st])
  path = r"https://api.census.gov/data/2020/acs/acs5/profile?get=NAME,DP04_0074PE&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
  File = folderPath + "kitchen_facilities_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

  df = pd.read_json (path)
  df.to_csv (File, index = None)

# %%
#internet_access

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/internet_access/"


for st in states:
  #print(st)
  #print(states[st])
  
  #os.mkdir("temp")

  FIPSStateNumericCode = str(st).zfill(2)
  OfficialUSPSCode = str(states[st])
  path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME,DP04_0075PE&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
  File = folderPath + "internet_access_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

  df = pd.read_json (path)
  df.to_csv (File, index = None)

# %%
#heat_electricity

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/heat_electricity/"


for st in states:
  #print(st)
  #print(states[st])
  
  #os.mkdir("temp")

  FIPSStateNumericCode = str(st).zfill(2)
  OfficialUSPSCode = str(states[st])
  path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME,DP04_0075PE&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
  File = folderPath + "heat_electricity_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

  df = pd.read_json (path)
  df.to_csv (File, index = None)

# %%
#internet_access

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}


races = {"White":"S2802_C05_005E","Black_or_African_American":"S2802_C05_006E","American_Indian_or_Alaska_Native":"S2802_C05_007E","Asian":"S2802_C05_008E","Native_Hawaiian_or_Other_Pacific_Islander":"S2802_C05_009E","Some_other_race":"S2802_C05_010E","Two_or_more_races":"S2802_C05_011E","Hispanic_or_Latino_origin_(of_any_race)":"S2802_C05_012E","White_alone_not_Hispanic_or_Latino":"S2802_C05_013E"}
folderPath = "/content/drive/MyDrive/Alvee/DataSets/internet_access/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/internet_access_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#Transportation

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}


races = {"female": "S0801_C03_048E", "male": "S0801_C02_048E", "intersex": "S0801_C01_048E"}
folderPath = "/content/drive/MyDrive/Alvee/DataSets/Transportation/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Transportation_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#foreign_born

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}


races = {"White":"S0501_C03_015E","Black_or_African_American":"S0501_C03_016E","American_Indian_or_Alaska_Native":"S0501_C03_017E","Asian":"S0501_C03_018E","Native_Hawaiian_or_Other_Pacific_Islander":"S0501_C03_019E","Some_other_race":"S0501_C03_020E","Two_or_more_races":"S0501_C03_021E","Hispanic_or_Latino_origin_(of_any_race)":"S0501_C03_022E","White_alone_not_Hispanic_or_Latino":"S0501_C03_023E"}
folderPath = "/content/drive/MyDrive/Alvee/DataSets/foreign_born/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/foreign_born_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#Employment

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}


races = {"White":"S2301_C04_012E","Black_or_African_American":"S2301_C04_013E","American_Indian_or_Alaska_Native":"S2301_C04_014E","Asian":"S2301_C04_015E","Native_Hawaiian_or_Other_Pacific_Islander":"S2301_C04_016E","Some_other_race":"S2301_C04_017E","Two_or_more_races":"S2301_C04_018E","Hispanic_or_Latino_origin_(of_any_race)":"S2301_C04_019E","White_alone_not_Hispanic_or_Latino":"S2301_C04_020E"}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/Employment/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Employment_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#Disability
# There is some error in this call. need to figure it out.

import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {
  "White":"S1810_C03_004E",
  "Black_or_African_American":"S1810_C03_005E",
  "American_Indian_or_Alaska_Native":"S1810_C03_006E",
  "Asian":"S1810_C03_007E",
  "Native_Hawaiian_or_Other_Pacific_Islander":"S1810_C03_008E",
  "Some_other_race":"S1810_C03_009E",
  "Two_or_more_races":"S1810_C03_010E",
  "Hispanic_or_Latino_origin_(of_any_race)":"S1810_C03_011E",
  "White_alone_not_Hispanic_or_Latino":"S1810_C03_012E"
}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/Disability/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Disability_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-158debbf6792> in <module>
#      36     File = filePath + "/Disability_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"
#      37
# ---> 38     df = pd.read_json (path)
#      39     df.to_csv (File, index = None)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#Education


import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {
            "White": "S1501_C02_029E",
            "Black or African American": "S1501_C02_035E",
            "American Indian or Alaska Native": "S1501_C02_038E",
            "Asian": "S1501_C02_041E",
            "Native Hawaiian or Other Pacific Islander": "S1501_C02_044E",
            "Some other race": "S1501_C02_047E",
            "Two or more races": "S1501_C02_050E",
            "Hispanic or Latino origin (of any race)": "S1501_C02_053E",
            "White alone, not Hispanic or Latino": "S1501_C02_032E",
}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/Education/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Education_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#Poverty


import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {
            "White": "S1701_C03_013E",
            "Black or African American": "S1701_C03_014E",
            "American Indian or Alaska Native": "S1701_C03_015E",
            "Asian": "S1701_C03_016E",
            "Native Hawaiian or Other Pacific Islander": "S1701_C03_017E",
            "Some other race": "S1701_C03_018E",
            "Two or more races": "S1701_C03_019E",
            "Hispanic or Latino origin (of any race)": "S1701_C03_020E",
            "White alone, not Hispanic or Latino": "S1701_C03_021E",
}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/Poverty/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Poverty_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#Income


import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {
            "White": "S1903_C03_002E",
            "Black or African American": "S1903_C03_003E",
            "American Indian or Alaska Native": "S1903_C03_004E",
            "Asian": "S1903_C03_005E",
            "Native Hawaiian or Other Pacific Islander": "S1903_C03_006E",
            "Some other race": "S1903_C03_007E",
            "Two or more races": "S1903_C03_008E",
            "Hispanic or Latino origin (of any race)": "S1903_C03_009E",
            "White alone, not Hispanic or Latino": "S1903_C03_010E",
}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/Income/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/Income_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)

# %%
#SNAP


import pandas as pd
import os
states = {1:'AL',   2:'AK', 4:'AZ', 5:'AR', 6:'CA', 8:'CO', 9:'CT', 10:'DE',    11:'DC',    12:'FL',    13:'GA',    15:'HI',    16:'ID',    17:'IL',    18:'IN',    19:'IA',    20:'KS',    21:'KY',    22:'LA',    23:'ME',    24:'MD',    25:'MA',    26:'MI',    27:'MN',    28:'MS',    29:'MO',    30:'MT',    31:'NE',    32:'NV',    33:'NH',    34:'NJ',    35:'NM',    36:'NY',    37:'NC',    38:'ND',    39:'OH',    40:'OK',    41:'OR',    42:'PA',    44:'RI',    45:'SC',    46:'SD',    47:'TN',    48:'TX',    49:'UT',    50:'VT',    51:'VA',    53:'WA',    54:'WV',    55:'WI',    56:'WY'}

races = {
    "White": "S2201_C02_025E",
    "Black or African American": "S2201_C02_026E",
    "Asian": "S2201_C02_028E",
    "Native Hawaiian or Other Pacific Islander": "S2201_C02_029E",
    "American Indian or Alaska Native": "S2201_C02_027E",
    "Two or more races": "S2201_C01_031E",
}

folderPath = "/content/drive/MyDrive/Alvee/DataSets/SNAP/"

for race in races:
  folderName = races[race]+"_"+race
  filePath = folderPath + folderName 
  os.mkdir(filePath)

  for st in states:
    #print(st)
    #print(states[st])
    
    #os.mkdir("temp")

    FIPSStateNumericCode = str(st).zfill(2)
    OfficialUSPSCode = str(states[st])
    path = r"https://api.census.gov/data/2020/acs/acs5/subject?get=NAME," + races[race] + "&for=tract:*&in=state:"+ str(FIPSStateNumericCode) + "%20county:*"
    File = filePath + "/SNAP_"+FIPSStateNumericCode+"_"+ OfficialUSPSCode +".csv"

    df = pd.read_json (path)
    df.to_csv (File, index = None)
